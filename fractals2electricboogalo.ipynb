# %%
# Define the default save directory
default_save_dir = "/home/luca/Downloads/"
from penkit.fractal.l_systems import l_system
from penkit.preview import show_layer
from penkit.textures.util import rotate_texture

# %%
# dragon curve
dragon_curve = l_system(
    axiom='F', 
    transformations={
        'F': 'F+G', 'G': 'F-G'
    }, 
    iterations=15, 
    angle=90)
show_layer(dragon_curve)

# %%
from penkit.write import write_plot

# Save the plot as SVG using penkit.write
write_plot([dragon_curve], f"{default_save_dir}dragoncurve3.svg", width=279, height=216, unit="mm")

# %%
peano_curve = l_system(
    axiom='F',
    transformations={
        'F': 'F+F-F-F-F+F+F+F-F'
    },
    iterations=4,
    angle=90
)

#peano_curve = rotate_texture(peano_curve, 37)

show_layer(peano_curve)

# %%
write_plot([peano_curve], f"{default_save_dir}peanocurve1.svg", width=279, height=216, unit="mm")

# %%
peano_curve2electricboogaloo = l_system(
    axiom='X',
    transformations={
        'X': 'XFYFX+F+YFXFY-F-XFYFX',
        'Y': 'YFXFY-F-XFYFX+F+YFXFY'
    },
    iterations=4,
    angle=90
)

show_layer(peano_curve2electricboogaloo)

# %%
sierpinski_carpet = l_system(
    axiom='F',
    transformations={
        'F': 'FFF[+FFF+FFF+FFF]'
    },
    iterations=5,
    angle=90
)

show_layer(sierpinski_carpet)

# %%
sierpinski_arrowhead = l_system(
    axiom='F--XF--F--XF',
    transformations={
        'X': 'XF+F+XF--F--XF+F+X',
        'F': 'F'
    },
    iterations=7,
    angle=45
)

sierpinski_arrowhead = rotate_texture(sierpinski_arrowhead, 45)
show_layer(sierpinski_arrowhead)

# %%
write_plot([sierpinski_arrowhead], f"{default_save_dir}sierpinskiarrowhead2.svg", width=279, height=216, unit="mm")

# %%
sierpinski_triangle = l_system(
    axiom='F-G-G',
    transformations={
        'F': 'F-G+F+G-F',
        'G': 'GG'
    },
    iterations=7,
    angle=120
)

sierpinski_triangle = rotate_texture(sierpinski_triangle, -30)

show_layer(sierpinski_triangle)

# %%
write_plot([sierpinski_triangle], f"{default_save_dir}sierpinskitriangle1.svg", width=279, height=216, unit="mm")

# %%
quadratic_koch_island = l_system(
    axiom='F-F-F-F',
    transformations={
        'F': 'F-F+F+FF-F-F+F'
    },
    iterations=4,
    angle=90
)

show_layer(quadratic_koch_island)

# %%
quadratic_koch_island_reversed = l_system(
    axiom='F+F+F+F',
    transformations={
        'F': 'F+F-F-FFF+F+F-F'
    },
    iterations=4,
    angle=90
)

show_layer(quadratic_koch_island_reversed)

# %%
quadratic_koch_island_reversed2electricboogaloo = l_system(
    axiom='F+F+F+F',
    transformations={
        'F': 'F-FF+FF+F+F-F-FF+F+F-F-FF-FF+F'
    },
    iterations=4,
    angle=90
)

show_layer(quadratic_koch_island_reversed2electricboogaloo)

# %%
koch_curve_3_now_I_have_to_pee = l_system(
    axiom='F+F+F+F',
    transformations={
        'F': 'F+F-F-FF+F+F-F'
    },
    iterations=4,
    angle=90
)

show_layer(koch_curve_3_now_I_have_to_pee)

# %%
board = l_system(
    axiom='F+F+F+F',
    transformations={
        'F': 'FF+F+F+F+FF'
    },
    iterations=4,
    angle=90
)

show_layer(board)

# %%
box_thingy = l_system(
    axiom='F',
    transformations={
        "F": "F+F-F-F-G+F+F+F-F",
        "G": "GGG"
    },
    iterations=5,
    angle=90
)

box_thingy = rotate_texture(box_thingy, 45)

show_layer(box_thingy)

# %%
triangle_party = l_system(
    axiom='F+F+F',
    transformations={
        'F': 'F+FF-F'
    },
    iterations=5,
    angle=120
)

triangle_party = rotate_texture(triangle_party, 30)

show_layer(triangle_party)

# %%
triangle_party2electricboogaloo = l_system(
    axiom='X',
    transformations={
        'F': 'F',
        'X': 'FY+FYFY-FY',
        'Y': 'FX-FXFX+FX'
    },
    iterations=6,
    angle=120
)

show_layer(triangle_party2electricboogaloo)

# %%
# Alien
alien = l_system(
    axiom='X',
    transformations={
        'X': '[@Q2@I2-FX]G[@Q2@I2---FX]',
        'F': ''
    },
    angle=11,
    iterations=10
)

show_layer(alien)

# %%
# Bush
bush = l_system(
    axiom='++++F',
    transformations={
        'F': 'FF-[-F+F+F]+[+F-F-F]'
    },
    iterations=5,
    angle=16
)

show_layer(bush)

# %%
# Cross
cross = l_system(
    axiom='FX',
    transformations={
        'F': '',
        'X': 'FX+FX+FXFY-FY-',
        'Y': '+FX+FXFY-FY-FY'
    },
    iterations=5,
    angle=90
)

show_layer(cross)

# %%
# Dekking
dekking = l_system(
    axiom='C32WC06ZC15YC06X',
    transformations={
        'F': '',
        'W': 'FW+F-XFW-F+Z',
        'X': '++F--Y-F+Z++F--Y-F+Z',
        'Y': '++F--Y+F-X',
        'Z': 'FW+F-X'
    },
    iterations=6,
    angle=90
)

show_layer(dekking)

# %%
# Doily
doily = l_system(
    axiom='F--F--F--F--F--F',
    transformations={
        'F': '-F[--F--F]++F--F+'
    },
    iterations=5,
    angle=45
)

show_layer(doily)

# %%
# dekking2electricboogaloo
dekking2electricboogaloo = l_system(
    axiom='X+X+X',
    transformations={
        'X': 'FY+GX-FY',
        'Y': 'GX+FY-GX',
        'F': '',
        'G': ''
    },
    iterations=6,
    angle=120
)

show_layer(dekking2electricboogaloo)

# %%
# Doublecrossmed
doublecrossmed = l_system(
    axiom='+X',
    transformations={
        'X': 'X-F-Y-F-X+F+Y+F+X+F+Y-F-X-F-Y',
        'Y': 'X+F+Y+F+X-F-Y-F-X-F-Y+F+X+F+Y'
    },
    iterations=4,
    angle=45
)

show_layer(doublecrossmed)

# %%
# Doily-c
doily_c = l_system(
    axiom='C32F--C36F--C40F--C44F--C48F--C52F',
    transformations={
        'F': '-F[--F--F]++F--F+'
    },
    iterations=5,
    angle=30
)

show_layer(doily_c)

# %%
# Doily leaf
doilyleaf = l_system(
    axiom='F--F--F--F--F--F',
    transformations={
        'F': '-F[--F--F]++F[++F--F]--F+'
    },
    iterations=5,
    angle=12
)

show_layer(doilyleaf)

# %%
# DragonCurd
weird_dragon = l_system(
    'SU',
    {
        'F': 'F',
        'G': 'G',
        'S': 'FS+G-X',
        'T': '++F--U+G-X',
        'U': '++F--U-G+Z',
        'V': 'FS-G+Z',
        'W': 'GW+F-T',
        'X': '++G--Y+F-T',
        'Y': '++G--Y-F+V',
        'Z': 'GW-F+V'
    },
    iterations=7,
    angle=90
)

show_layer(weird_dragon)

# %%
# Dragonrnd
idekanymore = l_system(
    'X',
    {
        'F': 'F',
        'X': 'FX+@0.500FZ@2.00+FY',
        'Y': 'FX-@0.500FZ@2.00-FY',
        'Z': 'FZ'
    },
    iterations=8,
    angle=45
)

show_layer(idekanymore)

# %%
# Fass1
board = l_system(
    '-L',
    {
        'L': 'LF+RFR+FL-F-LFLFL-FRFR+',
        'R': '-LFLF+RFRFR+F+RF-LFL-FR'
    },
    iterations=4,
    angle=90
)

show_layer(board)

# %%
# Fass2
fass2 = l_system(
    '-L',
    {
        'L': 'LFLF+RFR+FLFL-FRF-LFL-FR+F+RF-LFL-FRFRFR+',
        'R': '-LFLFLF+RFR+FL-F-LF+RFR+FLF+RFRF-LFL-FRFR'
    },
    iterations=3,
    angle=90
)

show_layer(fass2)

# %%
# FracRhombusTile
frac_rhombus_tile = l_system(
    'F',
    {
        'F': '[-F++G-]+F--G+',
        'G': '[-F++G-]+F--G+'
    },
    iterations=5,
    angle=30
)

show_layer(frac_rhombus_tile)

# %%
# Frame
frame = l_system(
    'YXY-YXY-YXY-YXY',
    {
        'F': 'F',
        'X': 'FX+FX+FXFYFX+FXFY-FY-FY-',
        'Y': '+FX+FX+FXFY-FYFXFY-FY-FY'
    },
    iterations=3,
    angle=90
)

show_layer(frame)

# %%
# Grid
grid = l_system(
    'F',
    {
        'F': 'F[+F][-F]F'
    },
    iterations=5,
    angle=90
)

show_layer(grid)

# %%
# Grid1
grid1 = l_system(
    'X',
    {
        'X': 'Y',
        'Y': 'F',
        'F': 'F[+F][-F]F'
    },
    iterations=8,
    angle=90
)

show_layer(grid1)

# %%
# Hex
hex_system = l_system(
    'F',
    {
        'F': '-F+F+G[+F+F]-',
        'G': 'GG'
    },
    iterations=5,
    angle=60
)

show_layer(hex_system)

# %%
# Hex1
hex1 = l_system(
    'F',
    {
        'F': '-F+F+F[+F+F+F]-'
    },
    iterations=5,
    angle=60
)

show_layer(hex1)

# %%
# Hilbert
hilbert = l_system(
    'X',
    {
        'X': '-YF+XFX+FY-',
        'Y': '+XF-YFY-FX+'
    },
    iterations=5,
    angle=90
)

show_layer(hilbert)

# %%
# Hilbert1
hilbert1 = l_system(
    'Z',
    {
        'Z': '-C32YC15F+C32XC15FC32X+C15FC32Y-',
        'X': '-YF+XFX+FY-',
        'Y': '+XF-YFY-FX+'
    },
    iterations=5,
    angle=90
)

show_layer(hilbert1)

# %%
# Hiway
hiway = l_system(
    'FX',
    {
        'X': 'FX+FY',
        'Y': 'FX-FY',
        'F': 'F'
    },
    iterations=10,
    angle=90
)


show_layer(hiway)

# %%
# Hiway1
hiway1 = l_system(
    'U',
    {
        'F': 'F',
        'G': 'G',
        'U': 'V',
        'V': 'C32FX+[+++@0.5GW---C40@Q2FZ]+C48FY',
        'X': 'FX+[+++@0.5GW---C40@Q2FZ]+FY',
        'Y': 'FX-[---@0.5GW+++C40@Q2FZ]-FY',
        'Z': 'FZ',
        'W': 'GW'
    },
    iterations=10,
    angle=45
)

show_layer(hiway1)

# %%
# Hiwayint
hiwayint = l_system(
    'S',
    {
        'F': 'F',
        'S': 'X+F-T',
        'T': '++F--U+F-T',
        'U': 'Z-F+V',
        'V': 'FS-F+V',
        'W': 'FSW',
        'X': 'XY',
        'Y': '++F--UY',
        'Z': 'ZW'
    },
    iterations=12,
    angle=90
)

show_layer(hiwayint)

# %%
# Hiwaymed
hiwaymed = l_system(
    '-X',
    {
        'X': 'X+F+Y',
        'Y': 'X-F-Y'
    },
    iterations=12,
    angle=45
)

show_layer(hiwaymed)

# %%
# Hiwaymed-x
hiwaymed_x = l_system(
    'S',
    {
        'F': 'F',
        'S': 'FS+F-T',
        'T': '+F-U+F-T',
        'U': '++F--V++F--W',
        'V': '++F--V-F+X',
        'W': '-F+Y++F--W',
        'X': '-F+Y-F+X',
        'Y': 'FSFZ',
        'Z': '+F-UFZ'
    },
    iterations=12,
    angle=90
)

show_layer(hiwaymed_x)

# %%
# Isocepent
isocepent = l_system(
    'W',
    {
        'W': '++[-@1.618033989F@I1.618033989++++F]FX--[++@1.618033989F----F]FW--[--@1.618033989F++++F]FY++',
        'X': '-[+@1.618033989F@I1.618033989----F]FZ++[--@1.618033989F++++F]FY-',
        'Y': '--[+@1.618033989F@I1.6180339898----F]FZ++[--@1.618033989F++++F]FY++[++@1.618033989F----F]FW--',
        'Z': '+[-@1.618033989F@I1.618033989++++F]FX--[++@1.618033989F----F]FW+',
        'F': 'F'
    },
    iterations=6,
    angle=36
)

show_layer(isocepent)

# %%
# Isocepent-1
isocepent_1 = l_system(
    'S',
    {
        'S': 'W',
        'W': '++[-@1.618033989F@I1.618033989++++F]FX--[++@1.618033989F----F]FW--[--@1.618033989F++++F]FY++',
        'X': '-[+@1.618033989F@I1.618033989----F]FZ++[--@1.618033989F++++F]FY-',
        'Y': '--[+@1.618033989F@I1.6180339898----F]FZ++[--@1.618033989F++++F]FY++[++@1.618033989F----F]FW--',
        'Z': '+[-@1.618033989F@I1.618033989++++F]FX--[++@1.618033989F----F]FW+',
        'F': 'F'
    },
    iterations=6,
    angle=36
)


show_layer(isocepent_1)

# %%
# Isocepent-2
isocepent_2 = l_system(
    'S',
    {
        'S': 'Z',
        'W': '++[-@1.618033989F@I1.618033989++++F]FX--[++@1.618033989F----F]FW--[--@1.618033989F++++F]FY++',
        'X': '-[+@1.618033989F@I1.618033989----F]FZ++[--@1.618033989F++++F]FY-',
        'Y': '--[+@1.618033989F@I1.6180339898----F]FZ++[--@1.618033989F++++F]FY++[++@1.618033989F----F]FW--',
        'Z': '+[-@1.618033989F@I1.618033989++++F]FX--[++@1.618033989F----F]FW+',
        'F': 'F'
    },
    iterations=7,
    angle=36
)

show_layer(isocepent_2)

# %%
# isocright
isocright = l_system(
    'X',
    {
        'X': '+Y-F-Y+',
        'Y': '-X+F+X-'
    },
    iterations=10,
    angle=45
)

show_layer(isocright)

# %%
# KochCurve
KochCurve = l_system(
    'F',
    {
        'F': 'F+F--F+F'
    },
    iterations=5,
    angle=60
)

show_layer(KochCurve)

# %%
# Lace
Lace = l_system(
    'w',
    {
        'w': '+++x--F--zFx+',
        'x': '---w++F++yFw-',
        'y': '+zFx--F--z+++',
        'z': '-yFw++F++y---'
    },
    iterations=7,
    angle=30
)

show_layer(Lace)

# %%
# Leaf2
LEAF2 = l_system(
    'A',
    {
        'A': 'F[+X]FB',
        'B': 'F[-Y]FA',
        'X': 'A',
        'Y': 'B',
        'F': '@1.36F@I1.36'
    },
    iterations=8,
    angle=45
)

show_layer(LEAF2)

# %%
# LawnInSpring
LAWNINSPRING = l_system(
    'C49X',
    {
        'X': '[+++++F-F-FZ]GX++++GY',
        'Y': '[+++++F-F-FZ]GX----GY',
        'Z': 'W',
        'W': 'U',
        'U': '[C44@.3[+++F]G++[+++F]G++[+++F]G++[+++F]G++[+++F]G++[+++F]G++[+++F]G++[+++F]G]Z',
        'F': '',
        'G': ''
    },
    iterations=5,
    angle=22.5
)

show_layer(LAWNINSPRING)

# %%
# Maze01
MAZE01 = l_system(
    'C40F+C48F+C56F',
    {
        'F': 'F+FF-F'
    },
    iterations=5,
    angle=120
)

show_layer(MAZE01)

# %%
# Maze&Fractal1
MAZEFRACTAL1 = l_system(
    'X',
    {
        'X': 'FY+FYFY-FY',
        'Y': 'FX-FXFX+FX',
        'F': ''
    },
    iterations=5,
    angle=120
)

show_layer(MAZEFRACTAL1)

# %%
# Moore
Moore = l_system(
    'X',
    {
        'F': '',
        'X': 'FX+FX+FXFYFX+FXFY-FY-FY-',
        'Y': '+FX+FX+FXFY-FYFXFY-FY-FY'
    },
    iterations=3,
    angle=90
)

show_layer(Moore)

# %%
# Peano1
Peano1 = l_system(
    'F',
    {
        'F': 'F-F+F+F+F-F-F-F+F'
    },
    iterations=4,
    angle=90
)

show_layer(Peano1)

# %%
# Peanomed
Peanomed = l_system(
    '-X',
    {
        'X': 'X+F+X-F-X-F-X-F-X+F+X+F+X+F+X-F-X'
    },
    iterations=3,
    angle=45
)

show_layer(Peanomed)

# %%
# Pentant
PENTANT = l_system(
    'X-X-X-X-X',
    {
        'F': '',
        'X': 'FX-FX-FX+FY+FY+FX-FX',
        'Y': 'FY+FY-FX-FX-FY+FY+FY'
    },
    iterations=3,
    angle=72
)

show_layer(PENTANT)

# %%
# PentaPlexity-0
PentaPlexity0 = l_system(
    'F++F++F++F++F',
    {
        'F': 'F++F++F|F-F++F'
    },
    iterations=3,
    angle=36
)

show_layer(PentaPlexity0)

# %%
# Pentigree
Pentigree = l_system(
    'F-F-F-F-F',
    {
        'F': 'F-F++F+F-F-F'
    },
    iterations=4,
    angle=72
)

show_layer(Pentigree)

# %%
# Pentive
Pentive = l_system(
    'W',
    {
        'F': '',
        'W': '++FX--FW--FY++',
        'X': '-FZ++FY-',
        'Y': '--FZ++FY++FW--',
        'Z': '+FX--FW+'
    },
    iterations=8,
    angle=36
)

show_layer(Pentive)

# %%
# Sierpinski
Sierpinski = l_system(
    'L--F--L--F',
    {
        'L': '+R-F-R+',
        'R': '-L+F+L-'
    },
    iterations=10,
    angle=45
)

show_layer(Sierpinski)

# %%
# SierpinskiCarpet
SIERPINSKICARPET = l_system(
    'F',
    {
        'F': 'F+F-F-F-G+F+F+F-F',
        'G': 'GGG'
    },
    iterations=4,
    angle=90
)

show_layer(SIERPINSKICARPET)

# %%
# Snowflake
SNOWFLAKE = l_system(
    'F--F--F',
    {
        'F': 'F+F--F+F'
    },
    iterations=5,
    angle=60
)

show_layer(SNOWFLAKE)

# %%
# Sphinx
Sphinx = l_system(
    'X',
    {
        'X': '+FF-YFF+FF--FFF|X|F--YFFFYFFF|',
        'Y': '-FF+XFF-FF++FFF|Y|F++XFFFXFFF|',
        'F': 'GG',
        'G': 'GG'
    },
    iterations=6,
    angle=60
)

show_layer(Sphinx)

# %%
# SquareGasket
SQUAREGASKET = l_system(
    'X',
    {
        'X': '+FXF+FXF+FXF+FXF',
        'F': 'FF'
    },
    iterations=5,
    angle=90
)

show_layer(SQUAREGASKET)

# %%
# Terdragon
Terdragon = l_system(
    'F',
    {
        'F': 'F+F-F'
    },
    iterations=7,
    angle=120
)

show_layer(Terdragon)

# %%
# ThreeTile
THREETILE = l_system(
    '[C32U]@Q3"',
    {
        '"': 'U',
        'U': '[+++@IQ3F----@2F]FX',
        'X': '+++[---@IQ3F++++@2F]FY----[-@2@IQ3F++++@I2F]FZ[---@IQ3F++++@2F]FY+',
        'Y': '---[+++@IQ3F----@2F]FX++++[+@2@IQ3F----@I2F]FW[+++@IQ3F----@2F]FX-',
        'Z': '-[+@2@IQ3F----@I2F]FW[+++@IQ3F----@2F]FX++++[+@2@IQ3F----@I2F]FW---',
        'W': '+[-@2@IQ3F++++@I2F]FZ[---@IQ3F++++@2F]FY----[-@2@IQ3F++++@I2F]FZ+++',
        'F': ''
    },
    iterations=5,
    angle=30
)

show_layer(THREETILE)

# %%
# Trigrid
TRIGRID = l_system(
    'F',
    {
        'F': 'F+F-F-FF+F+F-F'
    },
    iterations=5,
    angle=120
)

show_layer(TRIGRID)

# %%
# TwinDragonCurd
TWINDRAGONCURD = l_system(
    'FX+FX',
    {
        'X': 'FX+GY',
        'Y': 'GX-FY',
        'F': '',
        'G': ''
    },
    iterations=10,
    angle=90
)

show_layer(TWINDRAGONCURD)

# %%
# Weed
WEED = l_system(
    '+++++++++++++X',
    {
        'X': 'F[@.5+++++++++X]-F[@.4-----------!X]@.6X'
    },
    iterations=7,
    angle=7.2
)

show_layer(WEED)

# %%
# Xmastree
XMASTREE = l_system(
    'P',
    {
        'F': '',
        'P': '--<1FR++++<1FS--<1FU',
        'Q': '<1FT++<1FR----<1FS++',
        'R': '++<1FP----<1FQ++<1FT',
        'S': '<1FU--<1FP++++<1FQ--',
        'T': '+<1FU--<1FP+',
        'U': '-<1FQ++<1FT-'
    },
    iterations=7,
    angle=36
)

XMASTREE = rotate_texture(XMASTREE, -18)

show_layer(XMASTREE)
